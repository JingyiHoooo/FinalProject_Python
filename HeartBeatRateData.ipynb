# %%
#!/bin/python

import dropbox
import datetime
import schedule
import numpy
import string
import requests

from threading import Timer
import time
import sys

import csv

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import os

import matplotlib.dates as mdate

from matplotlib.ticker import MultipleLocator
from matplotlib.ticker import FormatStrFormatter

import pytz

# %%
class HR_Getting:
    
    def __init__():
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAtgRd7PtJ0xG4weBs1T_9Jp9pCxBjXccJlPYM7vYFC5RF')
        delta = datetime.timedelta(minutes=1)

    def E4(x, y):
        # Dropbox access token    
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAdn7IAKZUPyYJXhaYmllRlCFZwhYgt_m6fNafXq8DcgWK')

        # current time
        timestamp = datetime.datetime.now()
        # time gap
        delta = datetime.timedelta(minutes = 1)
        # time where the IBI file has been bulit
        filetime = timestamp - delta  

        # Re-formatting: datetime->String
        Str_filetime = filetime.strftime('%Y-%m-%d-%H-%M')

        # For testing only 
        # Str_filetime = '2019-06-22-22-25'

        # Set parameters for downloading the file 
        # Saving path
        download_path = 'C:\\FINAL_PROJECT\\IBI_Files\\IBIData'+Str_filetime +'.txt'
        # File location in dropbox    
        path = '/IBI/IBIData'+Str_filetime+'.txt'
        
        # Saving path
        #EDAdownload_path = 'C:\\FINAL_PROJECT\\EDA_Files\\GSRData'+Str_filetime +'.txt'
        # File location in dropbox    
        #EDApath = '/GSR/GSRData'+Str_filetime+'.txt'
        
        # to aviod network delay
        time.sleep(10)
        
        
        # try download
        try:
            dbx.files_download_to_file(download_path,path,None)

        except:
                print('IBIData'+Str_filetime+'.txt current is not exsit'+ 'or check the directory of download_path is exsit')
                pass
        else:
            print("Successful Downloading /Apps/E4Link" + path + " from Dropbox, overwriting " + download_path + "...")

            # A file downloaded, reformat the file
            resval = numpy.loadtxt(download_path)

            with open(download_path, 'r') as f:
                sum = 0
                count = 0
                lines = f.readlines()  # read the content
                for line in lines:
                    for value in line.split():
                        value = value.strip(string.whitespace)
                        sum += float(value)
                        count += 1
                
                f.close()
                
            aveIBI = sum / count
            bpm = int(60 / aveIBI)
            d5_bpm = int(bpm/5)
 
            x.append(Str_filetime)
            y.append(bpm)
                
            fig = HR_Getting.draw(x, y)

            with open('bpm_data.csv', 'a', newline='') as f:
                headers = ['time', 'bpm','d5_bpm' ]
                csv_write = csv.writer(f)
                
                if not os.path.getsize("bpm_data.csv"):     
                    # print('no headers')
                    csv_write.writerow(headers) # file doesn't exist yet, write a header
                
                csv_write.writerow([Str_filetime, bpm,d5_bpm])
                f.close()
                
            print('The average IBI value(s):', aveIBI, '\n' + 'The heart beat rate(bpm):', bpm, '\n')

    def bodyE4():
        x = []
        y = []
        #plt.ion()
        #plt.figure(1)
        schedule.every(1).minutes.do(HR_Getting.E4, x, y)
        while True:
            schedule.run_pending()

    def draw(x, y):
        plt.clf()
        plt.plot(x, y, '-r')
        plt.tick_params(axis='x', rotation=90)
        plt.title('bpm verus time')
        plt.xlabel('time')
        plt.ylabel('bpm')
        plt.pause(0.01)  # pause a bit so that plots are updated
        #plt.show
        #if 'qt5' in matplotlib.get_backend():
            #display.clear_output(wait=True)
            #display.display(plt.gcf())


if __name__ == "__main__":
    schedule.clear()
    
    IBIpath = 'C:\\FINAL_PROJECT\\IBI_Files' #location where you want to save your files
    IBIfolder = os.path.exists(IBIpath)
     
    if not IBIfolder:
        os.makedirs(IBIpath)
        print("folder created") 

        
    HR_Getting.bodyE4()
    print ('here')
# Out:
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-16-59.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-16-59.txt...
# The average IBI value(s): 0.7265953
# The heart beat rate(bpm): 82
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-00.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-00.txt...
# The average IBI value(s): 0.7422210250000001
# The heart beat rate(bpm): 80
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-01.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-01.txt...
# The average IBI value(s): 0.710970015
# The heart beat rate(bpm): 84
#
# IBIData2019-08-30-17-02.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-03.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-05.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-05.txt...
# The average IBI value(s): 0.750034329
# The heart beat rate(bpm): 79
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-06.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-06.txt...
# The average IBI value(s): 0.7673342303571429
# The heart beat rate(bpm): 78
#
# IBIData2019-08-30-17-07.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-08.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-08.txt...
# The average IBI value(s): 0.750034175
# The heart beat rate(bpm): 79
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-09.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-09.txt...
# The average IBI value(s): 0.70055275
# The heart beat rate(bpm): 85
#
# IBIData2019-08-30-17-10.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-12.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-12.txt...
# The average IBI value(s): 0.6406543
# The heart beat rate(bpm): 93
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-13.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-13.txt...
# The average IBI value(s): 0.6812810999999999
# The heart beat rate(bpm): 88
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-14.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-14.txt...
# The average IBI value(s): 0.6703431745
# The heart beat rate(bpm): 89
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-15.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-15.txt...
# The average IBI value(s): 0.7213870450000001
# The heart beat rate(bpm): 83
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-16.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-16.txt...
# The average IBI value(s): 0.6629767407142857
# The heart beat rate(bpm): 90
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-18.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-18.txt...
# The average IBI value(s): 0.690656547
# The heart beat rate(bpm): 86
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-19.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-19.txt...
# The average IBI value(s): 0.7005529
# The heart beat rate(bpm): 85
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-20.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-20.txt...
# The average IBI value(s): 0.6658958615384616
# The heart beat rate(bpm): 90
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-21.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-21.txt...
# The average IBI value(s): 0.65628002
# The heart beat rate(bpm): 91
#
# IBIData2019-08-30-17-22.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-24.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-24.txt...
# The average IBI value(s): 0.812537
# The heart beat rate(bpm): 73
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-25.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-25.txt...
# The average IBI value(s): 0.655820462647059
# The heart beat rate(bpm): 91
#
# IBIData2019-08-30-17-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-31.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-32.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-32.txt...
# The average IBI value(s): 0.67364194
# The heart beat rate(bpm): 89
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-33.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-33.txt...
# The average IBI value(s): 0.5729428799999999
# The heart beat rate(bpm): 104
#
# IBIData2019-08-30-17-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-37.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-38.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-38.txt...
# The average IBI value(s): 0.531274
# The heart beat rate(bpm): 112
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-39.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-39.txt...
# The average IBI value(s): 0.53127428
# The heart beat rate(bpm): 112
#
# IBIData2019-08-30-17-40.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-41.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-42.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-44.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-45.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-45.txt...
# The average IBI value(s): 0.5664321625000001
# The heart beat rate(bpm): 105
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-46.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-46.txt...
# The average IBI value(s): 0.6198200133333334
# The heart beat rate(bpm): 96
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-47.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-47.txt...
# The average IBI value(s): 0.6719057
# The heart beat rate(bpm): 89
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-48.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-48.txt...
# The average IBI value(s): 0.6771141799999999
# The heart beat rate(bpm): 88
#
# IBIData2019-08-30-17-50.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-51.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-52.txt current is not exsitor check the directory of download_path is exsit
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-53.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-53.txt...
# The average IBI value(s): 0.593777
# The heart beat rate(bpm): 101
#
# Successful Downloading /Apps/E4Link/IBI/IBIData2019-08-30-17-54.txt from Dropbox, overwriting C:\FINAL_PROJECT\IBI_Files\IBIData2019-08-30-17-54.txt...
# The average IBI value(s): 0.59377673
# The heart beat rate(bpm): 101
#
# IBIData2019-08-30-17-55.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-57.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-58.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-17-59.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-00.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-01.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-02.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-04.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-05.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-06.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-07.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-08.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-10.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-11.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-12.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-13.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-14.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-15.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-17.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-18.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-19.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-20.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-21.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-22.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-24.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-25.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-31.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-32.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-33.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-37.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-38.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-39.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-40.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-41.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-42.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-44.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-45.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-18-46.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-15.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-16.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-17.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-19.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-20.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-21.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-22.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-23.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-24.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-26.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-27.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-28.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-29.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-30.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-32.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-33.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-34.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-35.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-36.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-37.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-39.txt current is not exsitor check the directory of download_path is exsit
# IBIData2019-08-30-19-40.txt current is not exsitor check the directory of download_path is exsit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6b376e3fcb6e> in <module>
#     118
#     119
# --> 120     HR_Getting.bodyE4()
#     121     print ('here')
#
# <ipython-input-2-6b376e3fcb6e> in bodyE4()
#      91         schedule.every(1).minutes.do(HR_Getting.E4, x, y)
#      92         while True:
# ---> 93             schedule.run_pending()
#      94
#      95     def draw(x, y):
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending()
#     561     :data:`default scheduler instance <default_scheduler>`.
#     562     """
# --> 563     default_scheduler.run_pending()
#     564
#     565
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending(self)
#      91         """
#      92         runnable_jobs = (job for job in self.jobs if job.should_run)
# ---> 93         for job in sorted(runnable_jobs):
#      94             self._run_job(job)
#      95
#
# KeyboardInterrupt:
