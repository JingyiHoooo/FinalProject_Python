# %%
#!/bin/python

import dropbox
import datetime
import schedule
import numpy
import string
import requests

from threading import Timer
import time
import sys

import csv

import math
import random
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
import os

import matplotlib.dates as mdate

from matplotlib.ticker import MultipleLocator
from matplotlib.ticker import FormatStrFormatter

import pytz

# %%
class HR_Getting:
    
    def __init__():
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAdn7IAKZUPyYJXhaYmllRlCFZwhYgt_m6fNafXq8DcgWK')
        delta = datetime.timedelta(minutes=1)

    def E4(x, y):
        # Dropbox access token
        dbx = dropbox.Dropbox('lY_d3DAmzgAAAAAAAAAAdn7IAKZUPyYJXhaYmllRlCFZwhYgt_m6fNafXq8DcgWK')

        # current time
        timestamp = datetime.datetime.now()
        # time gap
        delta = datetime.timedelta(minutes=1)
        # time where the IBI file has been bulit
        filetime = timestamp - delta

        # Re-formatting: datetime->String
        Str_filetime = filetime.strftime('%Y-%m-%d-%H-%M')

        # For testing only
        #Str_filetime = '2019-07-27-23-22'

        # Set parameters for downloading the file
        # Saving path
        download_path = 'C:\\FINAL_PROJECT\\IBI_Files\\IBIData'+Str_filetime +'.txt'
        # File location in dropbox
        path = '/IBI/IBIData' + Str_filetime + '.txt'

        # try download
        try:
            dbx.files_download_to_file(download_path, path, None)
        except:
            print('IBIData' + Str_filetime + '.txt current is not exsit')
            pass
        else:
            #print("Successful Downloading /Apps/E4Link" + path + " from Dropbox, overwriting " + download_path + "...")

            # A file downloaded, reformat the file
            resval = numpy.loadtxt(download_path)

            with open(download_path, 'r') as f:
                sum = 0
                count = 0
                lines = f.readlines()  # read the content
                for line in lines:
                    for value in line.split():
                        value = value.strip(string.whitespace)
                        sum += float(value)
                        count += 1
                
                f.close()
                
            aveIBI = sum / count
            bpm = int(60 / aveIBI)
 
            x.append(Str_filetime)
            y.append(bpm)
                
            fig = HR_Getting.draw(x, y)

            with open('bpm_data.csv', 'a', newline='') as f:
                csv_write = csv.writer(f)
                csv_write.writerow([Str_filetime, bpm])
            f.close()
            
            #return x.y
            print('The average IBI value(s):', aveIBI, '\n' + 'The heart beat rate(bpm):', bpm, '\n')

    def bodyE4():
        x = []
        y = []
        #plt.ion()
        #plt.figure(1)
        schedule.every(1).minutes.do(HR_Getting.E4, x, y)
        while True:
            schedule.run_pending()

    def draw(x, y):
        plt.clf()
        plt.plot(x, y, '-r')
        plt.tick_params(axis='x', rotation=90)
        plt.title('bpm verus time')
        plt.xlabel('time')
        plt.ylabel('bpm')
        plt.pause(0.01)  # pause a bit so that plots are updated
        #plt.show
        #if 'qt5' in matplotlib.get_backend():
            #display.clear_output(wait=True)
            #display.display(plt.gcf())


if __name__ == "__main__":
    schedule.clear()
    HR_Getting.bodyE4()
    print ('here')
# Out:
# The average IBI value(s): 0.828162925
# The heart beat rate(bpm): 72
# The average IBI value(s): 0.9473089975
# The heart beat rate(bpm): 63
# The average IBI value(s): 0.9168494113513515
# The heart beat rate(bpm): 65
# The average IBI value(s): 0.8225822921428569
# The heart beat rate(bpm): 72
# The average IBI value(s): 0.8742587750000002
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.856289193
# The heart beat rate(bpm): 70
# The average IBI value(s): 0.9263119421875002
# The heart beat rate(bpm): 64
# The average IBI value(s): 0.8945722021153851
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.8426311646296301
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8627288839393941
# The heart beat rate(bpm): 69
# The average IBI value(s): 0.8852149434883724
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.8708731993333335
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.9180107775000002
# The heart beat rate(bpm): 65
# The average IBI value(s): 0.8582710002439026
# The heart beat rate(bpm): 69
# The average IBI value(s): 0.8852149425581399
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.8758085395081973
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.8563760161111112
# The heart beat rate(bpm): 70
# The average IBI value(s): 0.842409891617648
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8454932516363641
# The heart beat rate(bpm): 70
# The average IBI value(s): 0.891707492888889
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.8469848013636369
# The heart beat rate(bpm): 70
# The average IBI value(s): 0.9104035263157895
# The heart beat rate(bpm): 65
# The average IBI value(s): 0.8221530182051282
# The heart beat rate(bpm): 72
# The average IBI value(s): 0.83563608
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8379289804166667
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8437886268181818
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8862905736000001
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.8063816115151513
# The heart beat rate(bpm): 74
# The average IBI value(s): 0.7396171877777776
# The heart beat rate(bpm): 81
# The average IBI value(s): 0.8114210735714288
# The heart beat rate(bpm): 73
# The average IBI value(s): 0.8738380823076921
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.9176556590909091
# The heart beat rate(bpm): 65
#
# IBIData2019-07-29-23-02.txt current is not exsit
# IBIData2019-07-29-23-03.txt current is not exsit
# IBIData2019-07-29-23-04.txt current is not exsit
# IBIData2019-07-29-23-05.txt current is not exsit
# IBIData2019-07-29-23-06.txt current is not exsit
# IBIData2019-07-29-23-07.txt current is not exsit
# IBIData2019-07-29-23-08.txt current is not exsit
# IBIData2019-07-29-23-09.txt current is not exsit
# IBIData2019-07-29-23-10.txt current is not exsit
# IBIData2019-07-29-23-11.txt current is not exsit
# IBIData2019-07-29-23-12.txt current is not exsit
# IBIData2019-07-29-23-13.txt current is not exsit
# IBIData2019-07-29-23-14.txt current is not exsit
# IBIData2019-07-29-23-15.txt current is not exsit
# IBIData2019-07-29-23-16.txt current is not exsit
# The average IBI value(s): 0.988681625
# The heart beat rate(bpm): 60
# The average IBI value(s): 0.8808996924999999
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.8661110831428573
# The heart beat rate(bpm): 69
# The average IBI value(s): 0.8995947535714286
# The heart beat rate(bpm): 66
# The average IBI value(s): 0.8962910267999998
# The heart beat rate(bpm): 66
# The average IBI value(s): 0.8637548194444445
# The heart beat rate(bpm): 69
# The average IBI value(s): 0.8431636012000002
# The heart beat rate(bpm): 71
# The average IBI value(s): 0.8991639708771934
# The heart beat rate(bpm): 66
# The average IBI value(s): 0.8775259699999999
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.9024718686666674
# The heart beat rate(bpm): 66
# The average IBI value(s): 0.8750400560869565
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.6992507675
# The heart beat rate(bpm): 85
# The average IBI value(s): 0.8759592247058827
# The heart beat rate(bpm): 68
# The average IBI value(s): 0.9117604970000001
# The heart beat rate(bpm): 65
# The average IBI value(s): 0.849176811034483
# The heart beat rate(bpm): 70
# The average IBI value(s): 0.8119121686000004
# The heart beat rate(bpm): 73
# The average IBI value(s): 0.8851508191176473
# The heart beat rate(bpm): 67
# The average IBI value(s): 0.9088027669642861
# The heart beat rate(bpm): 66
# The average IBI value(s): 0.8252330887499999
# The heart beat rate(bpm): 72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-cd17ff7ca248> in <module>
#      93 if __name__ == "__main__":
#      94     schedule.clear()
# ---> 95     HR_Getting.bodyE4()
#      96     print ('here')
#
# <ipython-input-4-cd17ff7ca248> in bodyE4()
#      75         schedule.every(1).minutes.do(HR_Getting.E4, x, y)
#      76         while True:
# ---> 77             schedule.run_pending()
#      78
#      79     def draw(x, y):
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending()
#     561     :data:`default scheduler instance <default_scheduler>`.
#     562     """
# --> 563     default_scheduler.run_pending()
#     564
#     565
#
# ~\Anaconda3\lib\site-packages\schedule\__init__.py in run_pending(self)
#      90         between but only once.
#      91         """
# ---> 92         runnable_jobs = (job for job in self.jobs if job.should_run)
#      93         for job in sorted(runnable_jobs):
#      94             self._run_job(job)
#
# KeyboardInterrupt:
